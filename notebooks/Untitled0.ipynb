# %% [markdown]
# Porting the studies:
# http://slidedeck.io/michelleful/SingaporeRoadnameOrigins
#
# Getting metro extract from
# https://mapzen.com/metro-extracts/
# I downloaded IMPOSM GEOJSON wich contains many geometry files including montreal_canada-roads.geojson

# %%
import geopandas as gpd
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
'''
df = gpd.read_file('../montreal_canada/montreal_canada-roads.geojson')
df.shape
'''

df = gpd.read_file('../boston_massachusetts/boston_massachusetts-roads.geojson')
df.shape
# Out:
# (27918, 13)

# %% [markdown]
# Notea that Singapore(700km^2) has half as many roads (shape = (59218, 13)) as Montreal metro(4258km^2) for a comparable population according to wikipedia Singapore=5.5M, Montreal(metro)=4M.

# %%
fig = plt.figure(figsize=(16, 16))
df.head(n=2000).plot()

# %% [markdown]
# Obviously this file contains more than just Montreal.  Let's try to keep only what is needed

# %%
df_admin = gpd.read_file('../montreal_canada/montreal_canada-admin.geojson')
df_admin.shape
# Out:
# (38, 6)

# %%
df_admin.head()
# Out:
#    admin_leve                                           geometry  id  \
# 0           8  POLYGON ((-73.61849181641402 45.48826234140293...   1
# 1           8  POLYGON ((-73.37881707868057 44.98191098395773...   2
# 2           8  POLYGON ((-73.65601701018861 45.48295626141797...   3
# 3           8  POLYGON ((-73.46162801892102 44.99203598771518...   4
# 4           8  POLYGON ((-73.90081971246458 45.43501864842609...   5
#
#            name  osm_id            type
# 0     Westmount -197561  administrative
# 1  Rouses Point -176180  administrative
# 2     Hampstead -197569  administrative
# 3     Champlain -176177  administrative
# 4  Beaconsfield -197578  administrative

# %%
print df_admin.iloc[0]['geometry'].representative_point()
# Out:
#    admin_leve                                           geometry  id  \
# 0           8  POLYGON ((-73.61849181641402 45.48826234140293...   1
# 1           8  POLYGON ((-73.37881707868057 44.98191098395773...   2
# 2           8  POLYGON ((-73.65601701018861 45.48295626141797...   3
# 3           8  POLYGON ((-73.46162801892102 44.99203598771518...   4
# 4           8  POLYGON ((-73.90081971246458 45.43501864842609...   5
#
#            name  osm_id            type
# 0     Westmount -197561  administrative
# 1  Rouses Point -176180  administrative
# 2     Hampstead -197569  administrative
# 3     Champlain -176177  administrative
# 4  Beaconsfield -197578  administrative
# POINT (-73.59942310164686 45.48471612580832)

# %%
fig = plt.figure(figsize=(16, 16))
df_admin.plot()

# %% [markdown]
# Let's keep the island only

# %%
df_admin['name']
# Out:
# 0                          Westmount
# 1                       Rouses Point
# 2                          Hampstead
# 3                          Champlain
# 4                       Beaconsfield
# 5                             Dorval
# 6                        Baie-D'Urfé
# 7            Sainte-Anne-de-Bellevue
# 8                Dollard-Des-Ormeaux
# 9                         Senneville
# 10                          Kirkland
# 11                     Pointe-Claire
# 12                        Mont-Royal
# 13                             Laval
# 14                     Montréal (06)
# 15                       Ville-Marie
# 16                      Saint-Armand
# 17                  Venise-en-Québec
# 18                             Noyan
# 19          Sainte-Anne-de-Sabrevois
# 20        Saint-Blaise-sur-Richelieu
# 21    Saint-Georges-de-Clarenceville
# 22                        Henryville
# 23          Saint-Jean-sur-Richelieu
# 24      Saint-Paul-de-l'Île-aux-Noix
# ...

# %%
#good_names = ['Laval (13)', 'Westmount', 'Montréal (06)'] 
good_names = ['Laval (13)', 'Montréal (06)'.decode('utf-8'),] 
fig = plt.figure(figsize=(16, 16))
df_admin[df_admin['name'].isin(good_names)].plot()
#df_admin[~df_admin['name'].isin(good_names)].plot()

# %%
#df_water = gpd.read_file('../montreal_canada/montreal_canada-waterareas.geojson')
#df_water.shape

# %%
#fig = plt.figure(figsize=(16, 16))
#df_water.head(1000).plot()

# %%
#df = df[df.geometry.within(somearea.geometry)]
df_mtl06 = df[df.geometry.within(df_admin[df_admin['name'].isin(good_names)])]

# %%
fig = plt.figure(figsize=(16, 16))
#df[df.geometry.within(df_admin[df_admin['name']=='Laval (13)'])].plot()
df[df.geometry.within(df_admin[df_admin['name']=='Laval (13)'].geometry)].plot()

# %% [markdown]
# Getting the shape file here
# http://donnees.ville.montreal.qc.ca/dataset/polygones-arrondissements/resource/89f4d6bd-c0e9-46c8-9e1d-d83aec0a132e

# %%
mtl_shp = gpd.GeoDataFrame.from_file('../limadmin-shp/LIMADMIN.shp')
mtl_shp.shape
# Out:
# (34, 10)

# %%
mtl_shp.head()
# Out:
#   ABREV          AIRE CODEID CODEMAMROT  MUNID                    NOM  NUM  \
# 0    OM   3813355.723     11      REM05  66023              Outremont    5
# 1    LS  25197267.822     22      REM17  66023                LaSalle   18
# 2    MR   7445560.042     62      66072  66023             Mont-Royal    2
# 3    VM  21500631.743      9      REM19  66023            Ville-Marie   20
# 4    PM   8151665.080      5      REM21  66023  Le Plateau-Mont-Royal   22
#
#        PERIM            TYPE  \
# 0  10836.670  Arrondissement
# 1  25259.849  Arrondissement
# 2  18314.038      Ville liée
# 3  26585.959  Arrondissement
# 4  13158.328  Arrondissement
#
#                                             geometry
# 0  POLYGON ((-73.62077559344179 45.52365087960285...
# 1  POLYGON ((-73.66610411073152 45.42179736598723...
# 2  POLYGON ((-73.6507508626002 45.52630735684696,...
# 3  POLYGON ((-73.53012910755166 45.53475802657721...
# 4  POLYGON ((-73.55923068985261 45.53989862427608...

# %%
outremont = mtl_shp.geometry[1]

# %%
in_om = df.geometry.within(outremont)

# %%
in_om.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
fig = plt.figure(figsize=(10, 10))
df[in_om].plot(colormap='Blues')

# %%
df.head()
# Out:
#   access  bridge    class                                           geometry  \
# 0   None       0  highway  LINESTRING (-74.44440960259588 45.552194637306...
# 1   None       0  highway  LINESTRING (-73.50856734724495 45.707237633973...
# 2   None       0  highway  LINESTRING (-73.8529825146727 45.4936175393405...
# 3   None       0  highway  LINESTRING (-73.82927614556513 45.439216892268...
# 4   None       1  highway  LINESTRING (-73.60982425798034 45.462115581186...
#
#    id                       name  oneway   osm_id     ref service  tunnel  \
# 0   1                Highway 417       1  1296222  ON 417    None       0
# 1   2    Autoroute Félix-Leclerc       1  3452446    A 40    None       0
# 2   3       Boulevard Saint-Jean       1  3453106    None    None       0
# 3   4               Autoroute 20       1  3453107    A 20    None       0
# 4   5  Autoroute Ville Marie Est       1  4320291    None    None       0
#
#         type  z_order
# 0   motorway        9
# ...

# %% [markdown]
# Now let's try again with openstreet map

# %%
help(df[in_om].plot())
# Out:
# Help on AxesSubplot in module matplotlib.axes._subplots object:
#
# class AxesSubplot(SubplotBase, matplotlib.axes._axes.Axes)
#  |  Method resolution order:
#  |      AxesSubplot
#  |      SubplotBase
#  |      matplotlib.axes._axes.Axes
#  |      matplotlib.axes._base._AxesBase
#  |      matplotlib.artist.Artist
#  |      __builtin__.object
#  |
#  |  Methods inherited from SubplotBase:
#  |
#  |  __init__(self, fig, *args, **kwargs)
#  |      *fig* is a :class:`matplotlib.figure.Figure` instance.
#  |
#  |      *args* is the tuple (*numRows*, *numCols*, *plotNum*), where
#  |      the array of subplots in the figure has dimensions *numRows*,
#  |      *numCols*, and where *plotNum* is the number of the subplot
#  |      being created.  *plotNum* starts at 1 in the upper left
#  |      corner and increases to the right.
#  |
#  |
#  |      If *numRows* <= *numCols* <= *plotNum* < 10, *args* can be the
#  |      decimal integer *numRows* * 100 + *numCols* * 10 + *plotNum*.
#  |
# ...

# %% [markdown]
# Following instructions...
# http://lenguyenthedat.com/drawing-maps-python/

# %%
import mplleaflet

# %%
#dftest = pd.DataFrame({'lng':[-74.51, -74.51, -74.51], 'lat':[45.56, 45.57, 45.59]})
#figll = plt.figure(figsize=(10, 10))
#dftest.plot(kind="scatter", x='', y='y', color='r')
#plt.scatter(x=dftest.lng,
#            y=dftest.lat,
#            color="red",
#            alpha=0.3,
#            s=150)
#plt.plot(-74.51, 45.56, c='m', alpha=.4)
#plt.scatter([-74.51, -74.51], [45.56, 45.57], c='m', edgecolor='k', alpha=.4, s=150)
#plt.scatter(-74.51, 45.56)
df[in_om].plot()
mplleaflet.display() # To display it right at the notebook.
#mplleaflet.display(fig=figll) # To display it right at the notebook.
#mplleaflet.show(fig=figll) # To output _map.html file and display it in your browser.
#ax = df[in_om].plot()
#mplleaflet.display(fig=ax.figure) # To display it right at the notebook.
#mplleaflet.show(fig=ax.figure) # To output _map.html file and display it in your browser.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dee0a246acef> in <module>()
#      10 #plt.scatter([-74.51, -74.51], [45.56, 45.57], c='m', edgecolor='k', alpha=.4, s=150)
#      11 #plt.scatter(-74.51, 45.56)
# ---> 12 df[in_om].plot()
#      13 mplleaflet.display() # To display it right at the notebook.
#      14 #mplleaflet.display(fig=figll) # To display it right at the notebook.
#
# NameError: name 'df' is not defined

# %%
df.head(n=10)
# Out:
#   access  bridge    class                                           geometry  \
# 0   None       0  highway  LINESTRING (-74.44440960259588 45.552194637306...
# 1   None       0  highway  LINESTRING (-73.50856734724495 45.707237633973...
# 2   None       0  highway  LINESTRING (-73.8529825146727 45.4936175393405...
# 3   None       0  highway  LINESTRING (-73.82927614556513 45.439216892268...
# 4   None       1  highway  LINESTRING (-73.60982425798034 45.462115581186...
# 5   None       0  railway  LINESTRING (-74.26309436862222 45.259983136310...
# 6   None       1  highway  LINESTRING (-73.57302032697383 45.492520851129...
# 7   None       0  highway  LINESTRING (-73.59877925653055 45.498924373696...
# 8   None       0  railway  LINESTRING (-73.92980383072444 45.414479716708...
# 9   None       0  highway  LINESTRING (-73.59343805637128 45.50145528936,...
#
#    id                       name  oneway   osm_id     ref service  tunnel  \
# ...

# %%
df[~df['class'].isin(['railway', 'man_made'])]['name'].head(n=10).to_csv('test.csv', encoding='utf-8')
#df.groupby('class').sum()
#print df[~df['class'].isin(['railway', 'man_made'])]['class'].unique()

# %%
df[~df['class'].isin(['railway', 'man_made']) & ~df['name'].isin([None, ])]['name'].head(n=1000).to_csv('test.csv', encoding='utf-8')
